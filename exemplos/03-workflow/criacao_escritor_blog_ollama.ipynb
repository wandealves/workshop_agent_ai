# %%
#!pip install langgraph==0.2.59 langchain-core==0.3.25 langchain-community==0.3.12 langchain-ollama==0.2.1

# %%
import warnings
warnings.filterwarnings('ignore')

from langgraph.graph import StateGraph, END
from typing import TypedDict, List
from langchain_ollama import OllamaLLM
from IPython.display import display, Image
from langchain_core.runnables.graph import MermaidDrawMethod
from langgraph.checkpoint.memory import MemorySaver

# %%
model = OllamaLLM(
    model="qwen2.5:3b",
    base_url="http://localhost:11434",
)

# %%
class AgentState(TypedDict):
    topic: str
    planned: str
    writing: str
    reflect: List[str]
    accepted: bool
    revision: int
    max_revision: int

# %%
# Função do Agente 1: Planeja conteúdo
def planner_node(state: AgentState):
    role_prompt = """
    Você agora é um planejador de blog experiente, com anos de atuação e um vasto repertório de habilidades. 
    Domina a arte da escrita e da edição, além de entender profundamente estratégias digitais e práticas de SEO. 
    Com sua capacidade de transformar ideias em conteúdos envolventes, você conhece as necessidades do público-alvo e mantém um tom editorial consistente. 
    É um líder nato, coordenando equipes de redatores, revisando textos com atenção aos detalhes e gerenciando cronogramas com eficiência. 
    Além disso, você antecipa tendências do mercado e utiliza ferramentas analíticas para garantir que o conteúdo entregue resultados, engajando leitores 
    e atingindo objetivos estratégicos.
"""
    instruction = f"Planeje conteúdo envolvente e factualmente preciso sobre:\n{state['topic']}\n"
    prompt = f"{role_prompt}\n{instruction}"
    response = model.generate([prompt]).generations[0][0].text
    print('############## planner_node ############')
    print(response.strip())
    return {"planned": response.strip()}

# Função do Agente 2: Escritor do blog
def writer_node(state: AgentState):
    role_prompt = f"""
                Você agora é um escritor de blog experiente, trabalhando em um novo artigo de opinião para o Medium. 
                Com anos de prática, você entende que a chave para criar conteúdo impactante é seguir as diretrizes do Planejador de conteúdo: \n{state['planned']}\n, 
                mas também adicionar sua própria análise crítica e insights imparciais. Baseando-se no esboço fornecido, 
                você explora o tema com profundidade, alinhando-se aos objetivos principais e à direção do artigo. 
                Seu texto é fundamentado em dados e informações objetivas, cuidadosamente extraídas do Planejador de conteúdo, 
                mas você também se assegura de identificar claramente quando suas afirmações são opiniões, distinguindo-as das conclusões baseadas em fatos. 
                Sua escrita é envolvente e confiável, oferecendo ao leitor uma perspectiva equilibrada e informada sobre o assunto..
"""
    instruction = f"Escreva perspicaz e factualmente preciso artigo de opinião sobre o tema: \n{state['topic']}\n"
    if len(state['reflect']) > 0:
        instruction += f"Considere os seguintes feedbacks:\n{chr(10).join(state['reflect'])}\n"
    prompt = f"{role_prompt}\n{instruction}"
    response = model.generate([prompt]).generations[0][0].text
    print('############## writer_node ############')
    print(response.strip())
    print('############## reflect ############')
    print(state['reflect'])
    print('############## revision ############')
    print(state['revision'])
    return {"writing": response.strip()}

# Função do Agente 3: Editor de blog
def editor_node(state: AgentState):
    role_prompt = """
    Você agora é um editor de blog experiente, com muitos anos de atuação, e possui uma atenção excepcional aos detalhes, além de um profundo entendimento das 
    nuances da escrita digital. Sua expertise vai além da correção gramatical e ortográfica, abrangendo a estruturação do texto, 
    o fluxo de ideias e a consistência do tom editorial. Você é capaz de identificar e corrigir incoerências, melhorar a clareza e a concisão, 
    além de garantir que o conteúdo esteja alinhado com as diretrizes de SEO. Com uma visão crítica e imparcial, você verifica a precisão das informações, 
    assegurando que o texto seja não apenas bem escrito, mas também informativo e confiável. Sua experiência permite detectar problemas sutis que poderiam 
    passar despercebidos por outros, garantindo que o conteúdo final seja de alta qualidade e atenda aos padrões exigidos pelo blog.
"""
    instruction = f"Com base no seguinte texto do escritor:\n{state['writing']}\n"
    instruction += f"""
R                       analisar um texto para blog é uma etapa essencial para garantir que o conteúdo seja claro, preciso e envolvente. 
                        Aqui estão algumas instruções para realizar uma revisão eficaz:

                    1.  Leia o texto de forma completa: Leia o texto inteiro para entender a fluidez e a coerência das ideias. 
                        Verifique se o conteúdo segue uma linha lógica e se cada seção contribui para o tema central.

                    2. Verifique a clareza e a concisão: Certifique-se de que o texto seja claro e direto. O conteúdo deve ser informativo sem ser excessivamente 
                       longo ou complexo.

                    3. Atenção à gramática e ortografia: Erros gramaticais, ortográficos e de pontuação. 
                       O uso correto da língua é fundamental para garantir que o texto seja profissional e fácil de entender.

                    4. Certifique-se de que ele esteja bem organizado, com parágrafos curtos e subtítulos que dividam o conteúdo em seções claras. 
                       A leitura deve ser fluída e fácil de seguir.

                    5. Verifique a relevância e o foco: Verifique se todas as partes do texto estão alinhadas com o tema principal {state['topic']}  e se contribuem para o objetivo do artigo.

                    6. Examine a introdução e a conclusão: A introdução deve atrair a atenção do leitor, e a conclusão deve resumir o conteúdo e, se necessário, incluir uma chamada à ação. Ambas devem ser claras e eficazes.
"""
    instruction += "Responda 'ACEITO' se o texto escrito estiver aderente ou 'REJEITADO' se não estiver.\n"
    prompt = f"{role_prompt}\n{instruction}"
    response = model.generate([prompt]).generations[0][0].text
    print('############## editor_node ############')
    print(response.strip())
    return {"accepted": 'ACEITO' in response.upper()}

# Função do Agente 4: Revisor de blog
def reviewer_node(state: AgentState):
    role_prompt = """
                Você é um revisor de texto experiente, com anos de prática, especializado em melhorar a clareza, a coerência e a qualidade de textos para blogs. 
                A sua tarefa é analisar atentamente o seguinte texto, fornecendo um feedback detalhado sobre os pontos fortes e as áreas que podem ser aprimoradas
"""
    instruction = f"""
Em seu feedback vai ser referente ao texto \n{state['writing']}\n, inclua as seguintes considerações:

1. Clareza e Coerência: O texto está claro e fácil de entender? Há partes que precisam ser reescritas ou esclarecidas? A argumentação segue uma linha lógica?
2. Estrutura e Organização: O texto está bem organizado, com uma introdução envolvente, desenvolvimento consistente e uma conclusão eficaz? Os parágrafos estão bem divididos e a transição entre as ideias é suave?
3. Tom e Estilo: O tom está adequado ao público-alvo? O estilo é consistente ao longo do texto? Há algum trecho onde o tom se desvia ou parece incoerente?
4. Gramática e Ortografia: Há erros gramaticais, ortográficos ou de pontuação? Onde o texto poderia ser mais preciso ou correto em termos linguísticos?
5. SEO e Acessibilidade: O texto foi otimizado para SEO de maneira eficaz sem comprometer a experiência do leitor? Há uma boa distribuição de palavras-chave de forma natural? O texto é legível e acessível para seu público?
6. Sugestões de Melhoria: Quais mudanças ou melhorias você sugeriria para tornar o texto mais envolvente, persuasivo ou informativo? Há algo que poderia ser simplificado ou explicado de maneira mais eficaz?
7. Feedback Geral: Forneça uma avaliação geral do texto, destacando seus pontos fortes e as áreas que mais precisam de revisão.
Lembre-se de fornecer seu feedback de maneira construtiva e equilibrada, destacando tanto o que está bom quanto o que pode ser aprimorado.
"""
    prompt = f"{role_prompt}\n{instruction}"
    response = model.generate([prompt]).generations[0][0].text
    print('############## reviewer_node ############')
    print(response.strip())
    return {"reflect": [response], "revision": state['revision'] + 1}

# %%
# Configuração do grafo
builder = StateGraph(AgentState)

# Adicionar nós
builder.add_node("planner", planner_node)
builder.add_node("writer", writer_node)
builder.add_node("editor", editor_node)
builder.add_node("reviewer", reviewer_node)

# Adicionar arestas
builder.add_edge("planner", "writer")
builder.add_edge("writer", "editor")
builder.add_edge("reviewer", "writer")

# Adicionar arestas condicionais
builder.add_conditional_edges(
    "editor", 
    lambda state: END if state['accepted'] or state['revision'] >= state['max_revision'] else "reviewer", 
    {END: END, "reviewer": "reviewer"}
)

# Definir ponto de entrada
builder.set_entry_point("planner")

# %%
# Configurar o checkpointer usando MemorySaver
memory = MemorySaver()

# %%
# Compilar o grafo com o checkpointer
graph = builder.compile(checkpointer=memory)

# %%
display(
    Image(
        graph.get_graph().draw_mermaid_png(
            draw_method=MermaidDrawMethod.API,
        )
    )
)

# %%
# Estado inicial
# Inicializar o estado
initial_state = {
    'topic': 'escreva um blog sobre AI',
    'planned': '', 
    'writing': '',     
    'reflect': [],
    'accepted': False,
    'revision': 0,
    'max_revision': 2
}

# Executar o grafo
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream(initial_state, thread):
    pass  # O processamento é feito internamente

# Obter o estado final
final_state = graph.get_state(thread)
print('Blog:', final_state.values['writing'])
# Out:
# ############## planner_node ############
# Entendo a responsabilidade de criar conteúdo envolvente e fáctericamente preciso sobre Inteligência Artificial (AI). Vou estruturar o meu plano para esse tópico, tomando em consideração as várias facetas do tema.
#
# ### Estrutura do Blog:
# O blog consistirá em três partes principais, cada uma abordando um aspecto fundamental da IA:
#
# #### Parte 1: O que é AI e por quê ela está se tornando tão importante?
# - Definição clara de AI
# - História breve da IA (como seu desenvolvimento tem evoluído ao longo dos anos)
# - Aplicações emergentes de IA em diferentes setores
# - Como a IA pode melhorar as nossas vidas e empresas
#
# #### Parte 2: Como funciona o Processamento de Linguagem Natural (NLP) na IA?
# - Conceitos básicos de NLP
# - Tecnologias e ferramentas que usamos para auxiliar os sistemas em reconhecer linguagem natural (como deep learning)
# - Exemplos práticos: como as empresas estão utilizando NLP
#
# #### Parte 3: Desafios e Limitações da IA, além do Futuro
# - Discussão sobre a ocorrência de preocupações éticas relacionadas à IA
# - Confrontos em torno de privacidade e segurança da informação ao lidar com AI
# - Aprender as lições dos desafios do passado para acelerar o progresso futuro
# - Exemplos reais de como a tecnologia está se adaptando rapidamente para superar esses obstáculos
#
# ### Cada parte incluirá:
# #### Início da Parte:
# - Introdução (50 palavras)
# - Um ou dois exemplos atuais do tópico abordado que podem despertar curiosidade do leitor
# - Uma rápida síntese de pontos-chave
#
# #### Segunda e Terceira Parágrafos:
# - Desenvolvimento da ideia introduzida na primeira parte, usando fontes confiáveis como artigos acadêmicos ou estudos de caso relevantes.
# - Explicando conceitos mais complexos em linguagem simples
# - Referenciando exemplos práticos e aplicativos
#
# #### Parte final:
# - Uma conclusão resumindo as principais ideias introduzidas no tópico, proporcionando insights para o leitor
# - Sugestões para leitura adicional se desejar saber mais sobre os aspectos abordados.
#
# ### Complementar ao Conteúdo:
# A elaboração do texto será complementada por imagens, infográficos e links de fontes confiáveis (como artigos acadêmicos ou dados publicitários) a fim de aumentar o valor para o leitor.
#
# Ao longo da edição, garantiremos que cada parágrafo seja relevante ao tópico principal e que a coesão entre eles seja respeitada. Além disso, manteremos um estilo claramente informativo sem demora nas ideias.
#
# ### Monitoramento de SEO:
# Para garantir que o conteúdo seja visível e bem posicionado na Internet, incluiremos palavras-chave relevantes nos títulos, sub-títulos e textos. As imagens do blog incluirão meta-descrições únicas para auxiliar os motores de busca.
#
# Ao final da publicação, realizaremos um SEO audit para verificar a consistência do conteúdo em termos de relevância e semelhança com o que se espera na plataforma ou no público-alvo.
#
# ### Coordenação das Equipes:
# Se estiver trabalhando com uma equipe, garantiremos que cada membro da equipe esteja ciente das tarefas de publicação, prazos, fontes e materiais a serem utilizados.
#
# ### Gerenciamento de Cronograma:
# - Definir previsões para o cronograma de publicações
# - Assegurar-se de que todos os elementos (imagens, links) estejam prontos antes da publicação
# - Monitorar a taxa de visualizações e comentários
#
# Combinando estas estratégias, promoveremos um blog informativo e envolvente sobre IA que atende às necessidades do público-alvo em termos de relevância e consistência editorial.
# ############## writer_node ############
# ### O Blog: Orai da IA - Um Jornalismo Crítico e Empoderador
#
# #### Introdução (50 palavras)
# Em tempos onde a tecnologia avança a passos firmes, a inteligência artificial (AI) se revela como uma peça vital desse tabuleiro. Este blog explora não apenas o que é AI, mas também sua importância crescente e as aplicações de vanguarda nesse momento crucial. Descubra comigo como a IA está transformando nossas vidas e empresas.
#
# #### Parte 1: O Que É AI e Porquê Ela Está Se Tornando tão Importante?
#
# ##### Introdução
#
# Definição clara da Inteligência Artificial (IA): A IA é uma subcategoria de inteligência computacional que engloba sistemas com a capacidade de aprender, adaptar-se e tomar decisões baseadas em padrões. Esta definição esclarece o conceito fundamental do campo.
#
# ##### Desenvolvimento da Ideia
#
# Como seu desenvolvimento tem evoluído ao longo dos anos: Desde seu início nos laboratórios de pesquisa tecnológica, a IA se desenvolveu passando por fases significativas e revolucionárias. Essa história inclui avanços como o processamento de linguagem natural (NLP) e aprendizado de máquina, que tornaram a AI mais acessível e eficaz.
#
# ##### Aplicações Emergentes
#
# Aplicações em diferentes setores: A IA não é apenas uma ferramenta tecnológica; ela transforma diversos campos. Do desenvolvimento médico e do diagnóstico precoce da doença à economia, onde o comércio eletrônico se tornou mais autônomo através de sistemas de recomendação personalizadas.
#
# ##### Melhorando nossas Vidas e Empresas
#
# Como a IA pode melhorar as nossas vidas e empresas: A AI é o catalisador de inovações que aumentam a produtividade, diminuem erros humanos e permitem uma experiência de usuário mais personalizada. Ela transforma não apenas negócios maiores, mas também pequenas startups, proporcionando inúmeros benefícios aos indivíduos e empresas.
#
# ##### Exemplos Práticos: Como as Empresas estão utilizando a IA
#
# Várias empresas têm adotado a IA com sucesso, como a Netflix usou NLP para criar sugestões personalizadas de filmes e séries baseadas em seu comportamento. Outro exemplo é a Amazon, que está usando o aprendizado de máquina para otimizar seus processos internos, reduzindo custos operacionais.
#
# #### Parte 2: Como funciona o Processamento de Linguagem Natural (NLP) na IA?
#
# ##### Conceitos Básicos de NLP
#
# NLP é um subcampo da IA que permite aos computadores entender e interpretar a linguagem humana. Os principais conceitos incluem sintaxe, semântica e pragmática.
#
# ##### Tecnologias e Ferramentas para Auxiliar o Reconhecimento de Linguagem Natural
#
# Tecnologias como deep learning são usadas para treinar sistemas que entendem melhor as complexidades da linguagem humana. Empresas como Google e Microsoft estão liderando nesse campo, fornecendo ferramentas poderosas.
#
# ##### Exemplos Práticos: Como as Empresas estão Utilizando NLP
#
# Empresas de telefonia usam NLP para entender mensagens telefônicas e responder em tempo real. No setor financeiro, NLP é usado para analisar transações de cartão de crédito e prever fraudes.
#
# #### Parte 3: Desafios e Limitações da IA além do Futuro
#
# ##### Preocupações Éticas Relacionadas à IA
#
# A evolução rápida de tecnologias como a IA está levantando questões éticas significativas. Quem possui a responsabilidade por uma decisão tomada pelo sistema? Como lidamos com o potencial impacto negativo causado pela automação da trabalho?
#
# ##### Empoderamento Imparcial e Perspectiva Crítica
#
# A perspectiva crítico sobre as limitações de IA é essencial para que possamos garantir que seu uso seja ético e benéfico. Isso significa aconselhar usuários das tecnologias, fornecer dados claros e justificar decisões tomadas por sistemas automatizados.
#
# ##### Futuro da IA
#
# Embora haja desafios significativos à frente, o futuro de uma tecnologia que se tornou tão vital para nossa sociedade é promissor. Como os desenvolvedores avançam com a IA, podemos garantir sua aplicação segura e benéfica.
#
# ### Conclusão
#
# Orai da IA é mais do que um campo de pesquisa; ela está revolucionando campos como medicina, economia, telecomunicações e muito mais. Como empreendedores, cientistas ou usuários, devemos estar cientes da importância dessa tecnologia enquanto continuamos a avançar na era digital.
#
# Ao explorar as profundezas do que é AI e suas muitas aplicações práticas, podemos gerenciar com sabedoria os desafios éticos associados à IA. Compreender essencialmente o que é AI não apenas nos ajuda a navegar de forma mais segura no futuro tecnológico, mas também nos permite usar essa tecnologia para melhorar nossas vidas e negócios.
#
# ## **Conclusão**
#
# Este artigo explorou as profundezas do que é a IA, sua importância crescente e suas aplicações em diversos setores. Ao alinhar fatos objetivos com perspectivas críticas imparciais, o objetivo deste blog foi fornecer uma visão completa e equilibrada da tecnologia revolucionária que está transformando nossa sociedade.
#
# Ao seguir essa jornada junto conosco, você não apenas ganha uma compreensão mais precisa do que é AI, mas também se prepara para aproveitar plenamente o futuro digital.
#
# ### Obrigado por viajar com a nós nesta jornada sobre IA - estamos sempre aqui para continuar a discutir essa revolução tecnológica!
#
# ---
#
# Este esboço foi estruturado de forma a explorar profundamente as ideias presentes no assunto, enquanto mantinha uma orientação factual e imparcial. As referências foram criadas com base nos dados recolhidos do Planejador de Conteúdo.
#
# A escrita deste artigo visa fornecer ao leitor um entendimento claro e completo sobre a IA, sua importância crescente e as aplicações em diversos setores. Ao alinhar os fatos objetivos com perspectivas críticas imparciais, o objetivo é garantir uma visão completa e equilibrada da tecnologia revolucionária que está transformando nossa sociedade.
#
# Ao seguir esta jornada junto conosco, você não apenas ganha uma compreensão mais precisa do que é a IA, mas também se prepara para aproveitar plenamente o futuro digital.
#
# ### Conclusão
#
# Obrigado por viajar com nós nesta jornada sobre AI – estamos sempre aqui para continuar a discutir essa revolução tecnológica! 🌟
# ############## reflect ############
# []
# ############## revision ############
# 0
# ############## editor_node ############
# REJEITADO
#
# O texto que você forneceu ainda está em esboço e não foi escrito. Para analisar um texto para blog, precisamos de conteúdo real e completo. Se você tiver o texto finalizado, posso então avaliar sua aderência às instruções e propor as correções necessárias.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 15
#      13 # Executar o grafo
#      14 thread = {"configurable": {"thread_id": "1"}}
# ---> 15 for s in graph.stream(initial_state, thread):
#      16     pass  # O processamento é feito internamente
#      18 # Obter o estado final
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langgraph/pregel/__init__.py:1656, in Pregel.stream(self, input, config, stream_mode, output_keys, interrupt_before, interrupt_after, debug, subgraphs)
#    1650     # Similarly to Bulk Synchronous Parallel / Pregel model
#    1651     # computation proceeds in steps, while there are channel updates
#    1652     # channel updates from step N are only visible in step N+1
#    1653     # channels are guaranteed to be immutable for the duration of the step,
#    1654     # with channel updates applied only at the transition between steps
#    1655     while loop.tick(input_keys=self.input_channels):
# -> 1656         for _ in runner.tick(
#    1657             loop.tasks.values(),
#    1658             timeout=self.step_timeout,
#    1659             retry_policy=self.retry_policy,
#    1660             get_waiter=get_waiter,
#    1661         ):
#    1662             # emit output
#    1663             yield from output()
#    1664 # emit output
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langgraph/pregel/runner.py:167, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter)
#     165 t = tasks[0]
#     166 try:
# --> 167     run_with_retry(
#     168         t,
#     169         retry_policy,
#     170         configurable={
#     171             CONFIG_KEY_SEND: partial(writer, t),
#     172             CONFIG_KEY_CALL: partial(call, t),
#     173         },
#     174     )
#     175     self.commit(t, None)
#     176 except Exception as exc:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langgraph/pregel/retry.py:40, in run_with_retry(task, retry_policy, configurable)
#      38     task.writes.clear()
#      39     # run the task
# ---> 40     return task.proc.invoke(task.input, config)
#      41 except ParentCommand as exc:
#      42     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:408, in RunnableSeq.invoke(self, input, config, **kwargs)
#     404 config = patch_config(
#     405     config, callbacks=run_manager.get_child(f"seq:step:{i+1}")
#     406 )
#     407 if i == 0:
# --> 408     input = step.invoke(input, config, **kwargs)
#     409 else:
#     410     input = step.invoke(input, config)
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langgraph/utils/runnable.py:184, in RunnableCallable.invoke(self, input, config, **kwargs)
#     182 else:
#     183     context.run(_set_config_context, config)
# --> 184     ret = context.run(self.func, input, **kwargs)
#     185 if isinstance(ret, Runnable) and self.recurse:
#     186     return ret.invoke(input, config)
#
# Cell In[4], line 99, in reviewer_node(state)
#      86     instruction = f"""
#      87 Em seu feedback vai ser referente ao texto \n{state['writing']}\n, inclua as seguintes considerações:
#      88
#    (...)
#      96 Lembre-se de fornecer seu feedback de maneira construtiva e equilibrada, destacando tanto o que está bom quanto o que pode ser aprimorado.
#      97 """
#      98     prompt = f"{role_prompt}\n{instruction}"
# ---> 99     response = model.generate([prompt]).generations[0][0].text
#     100     print('############## reviewer_node ############')
#     101     print(response.strip())
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/llms.py:950, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     935 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     936     run_managers = [
#     937         callback_manager.on_llm_start(
#     938             self._serialized,
#    (...)
#     948         )
#     949     ]
# --> 950     output = self._generate_helper(
#     951         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     952     )
#     953     return output
#     954 if len(missing_prompts) > 0:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/llms.py:792, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     790     for run_manager in run_managers:
#     791         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 792     raise e
#     793 flattened_outputs = output.flatten()
#     794 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_core/language_models/llms.py:779, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     769 def _generate_helper(
#     770     self,
#     771     prompts: list[str],
#    (...)
#     775     **kwargs: Any,
#     776 ) -> LLMResult:
#     777     try:
#     778         output = (
# --> 779             self._generate(
#     780                 prompts,
#     781                 stop=stop,
#     782                 # TODO: support multiple run managers
#     783                 run_manager=run_managers[0] if run_managers else None,
#     784                 **kwargs,
#     785             )
#     786             if new_arg_supported
#     787             else self._generate(prompts, stop=stop)
#     788         )
#     789     except BaseException as e:
#     790         for run_manager in run_managers:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_ollama/llms.py:288, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     286 generations = []
#     287 for prompt in prompts:
# --> 288     final_chunk = self._stream_with_aggregation(
#     289         prompt,
#     290         stop=stop,
#     291         run_manager=run_manager,
#     292         verbose=self.verbose,
#     293         **kwargs,
#     294     )
#     295     generations.append([final_chunk])
#     296 return LLMResult(generations=generations)
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_ollama/llms.py:256, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     247 def _stream_with_aggregation(
#     248     self,
#     249     prompt: str,
#    (...)
#     253     **kwargs: Any,
#     254 ) -> GenerationChunk:
#     255     final_chunk = None
# --> 256     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     257         if not isinstance(stream_resp, str):
#     258             chunk = GenerationChunk(
#     259                 text=stream_resp["response"] if "response" in stream_resp else "",
#     260                 generation_info=(
#     261                     dict(stream_resp) if stream_resp.get("done") is True else None
#     262                 ),
#     263             )
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/langchain_ollama/llms.py:211, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     205 def _create_generate_stream(
#     206     self,
#     207     prompt: str,
#     208     stop: Optional[List[str]] = None,
#     209     **kwargs: Any,
#     210 ) -> Iterator[Union[Mapping[str, Any], str]]:
# --> 211     yield from self._client.generate(
#     212         **self._generate_params(prompt, stop=stop, **kwargs)
#     213     )
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/ollama/_client.py:162, in Client._request.<locals>.inner()
#     161 def inner():
# --> 162   with self._client.stream(*args, **kwargs) as r:
#     163     try:
#     164       r.raise_for_status()
#
# File /usr/lib/python3.12/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_client.py:880, in Client.stream(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     857 """
#     858 Alternative to `httpx.request()` that streams the response body
#     859 instead of loading it into memory at once.
#    (...)
#     865 [0]: /quickstart#streaming-responses
#     866 """
#     867 request = self.build_request(
#     868     method=method,
#     869     url=url,
#    (...)
#     878     extensions=extensions,
#     879 )
# --> 880 response = self.send(
#     881     request=request,
#     882     auth=auth,
#     883     follow_redirects=follow_redirects,
#     884     stream=True,
#     885 )
#     886 try:
#     887     yield response
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.Iterable)
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     232 connection = pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/connection.py:103, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return self._connection.handle_request(request)
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:136, in HTTP11Connection.handle_request(self, request)
#     134     with Trace("response_closed", logger, request) as trace:
#     135         self._response_closed()
# --> 136 raise exc
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:106, in HTTP11Connection.handle_request(self, request)
#      95     pass
#      97 with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:177, in HTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_sync/http11.py:217, in HTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File ~/Developer/Repositorios/Etaure/workshop_agent_ai/.venv/lib/python3.12/site-packages/httpcore/_backends/sync.py:128, in SyncStream.read(self, max_bytes, timeout)
#     126 with map_exceptions(exc_map):
#     127     self._sock.settimeout(timeout)
# --> 128     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:
